# %%
#1. Guess a number is a game that prompts a player to guess a number between 0 and 9, which 
 #is randomly generated by the system. When the input given by the user matches the 
#number generated by the system then the user wins. The game should go as follows:
#Guess the number: 5
#Sorry, try again
#Guess the number: 3
#Sorry, try again
#Guess the number: 8
#You got it right! Congo!

import random
no1=eval(input("enter number between 0 to 9: "))
r=random.randint(0,9)
print("random number is:{}".format(r))
while no1==r:
    print("you got it right! congo!")
    no1=eval(input("enter number between 0 to 9: "))
    break
else:
    print("sorry!, try again")
    r=random.randint(0,9)
    no2=eval(input("enter number between 0 to 9: "))

print("random number is:{}".format(r))
while no2==r:
    print("you got it right! congo!")
    break
else:
    print("sorry!, try again")
    print("random number is:{}".format(r))
    no2=eval(input("enter number between 0 to 9: "))
    print("you got it right! congo!")
# Out:
# enter number between 0 to 9: 5
# random number is:1
# sorry!, try again
# enter number between 0 to 9: 3
# random number is:0
# sorry!, try again
# random number is:0
# enter number between 0 to 9: 0
# you got it right! congo!

# %%
import random
r=random.randint(0,9)
i=0
print("you have 3 attempts : ")
print("random number is:{}".format(r))
while i<3:
    number=eval(input("enter the number: "))
    if number<r:
        print("number is too low")
    elif number>r:
            print("number is too high")
    else:
            print("you win")
            break
    if i==1:
            print("enter any number again but its your last chance: ")
    if i==2:        
        print("sorry you lost")
    i+=1
# Out:
# you have 3 attempts :
# random number is:7
# enter the number: 5
# too low
# enter the number: 9
# too high
# enter any number again but its your last chance:
# enter the number: 7
# you win

# %%
import random
r=random.randint(0,9)
print("random number is:{}".format(r))
i=0
print("you have 1000 rupees : ")
balance=1000
while i<3: 
    number=eval(input("enter the number: "))
    if number==r:
        if i==0:
            print("correct answer, you win 5000 rupees credited in your account ")
            break
    if number<r:
        print("number is too low, you lost 500 rupees from balance")
        balance=balance-500
        print("your current balance is now : {}".format(balance))
    elif number>r:
        print("number is too high")
        balance=balance-500
        print("your current balance is now : {}".format(balance))
    else:
        print("correct answer, you win 1000 rupees credited in your account ")
        balance=balance+1000
        print("your current balance is now : {}".format(balance))
        break
    if balance>=500:
        if i==1:
            print("enter any number again but its your last chance: ")
    else:
        print("No suffitient balance to play... plz recharge")
        break
        if i==2:        
            print("sorry you lost 500 rupees")
            i+=1
# Out:
# random number is:7
# you have 1000 rupees :
# enter the number: 4
# number is too low, you lost 500 rupees from balance
# your current balance is now : 500
# enter the number: 9
# number is too high
# your current balance is now : 0
# No suffitient balance to play... plz recharge

# %%
#4
